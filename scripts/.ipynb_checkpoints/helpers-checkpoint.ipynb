# %%
import glob
import random
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import torch
from PIL import Image
from torchvision.transforms import ToTensor
from torchvision.transforms import ToPILImage
from torchvision.transforms import ToTensor

# %% [markdown]
# ## Find polygons on mask and make txt file

# %%
def find_polygons_save_txt_file(input_dir, output_dir, photo_dir):
    for j in os.listdir(input_dir):
        mask_value = []
        mask_polygon = []
        polygons = []
        image = None
        image_path = os.path.join(input_dir, j)
        photo_path = os.path.join(photo_dir, j)
        photo = cv2.imread(photo_path)
        # load the binary mask and get its contours
        mask_0 = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        mask_1 =  np.uint8(np.where(mask_0>0, 255, mask_0))
        
        mask_00 = cv2.imread(image_path)  
        mask_2 =  np.uint8(np.where(mask_00>0, [255, 255, 255],[0, 0, 0]))
        mask_NOT = np.uint8(mask_00)
        
        _, mask = cv2.threshold(mask_1, 1, 255, cv2.THRESH_BINARY)
        contours, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        for random_contour in contours: #contours on actual photo
            cv2.drawContours(photo, [random_contour], -1, (0,100,0), 3) #paint contour on photo
            x, y, w, h = cv2.boundingRect(random_contour) #boundingbox around the contour
            while True: #search point inside contours
                random_point = (np.random.randint(x, x + w), np.random.randint(y, y + h))
                if cv2.pointPolygonTest(random_contour, random_point, False) >= 0:
                    value = mask_NOT[random_point[1], random_point[0]][0] #get mask value from the point of the contour
                    mask_value.append(value-1) #add mask value to list
                    image = cv2.putText(photo, str(value-1), random_point, cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 1, cv2.LINE_AA)
                    break  

            polygon = []
            H, W = mask_1.shape
            for point in random_contour: #get points from contours
                x, y = point[0]
                polygon.append(x / W)
                polygon.append(y / H)
                
            if(len(polygon) % 2):
                print("ERROR", j)
                
            mask_polygon.append(polygon)
        with open('{}.txt'.format(os.path.join(output_dir, j)[:-4]), 'w') as f: # zapis punktów do pliku txt
            for num, polygon in enumerate(mask_polygon):
                for p_, p in enumerate(polygon):
                    if p_ == len(polygon)-1:
                        f.write('{}\n'.format(p))
                    elif p_ == 0:
                        f.write(str(mask_value[num]))
                        f.write(' {} '.format(p))
                    else:
                        f.write('{} '.format(p))

            f.close()
            name_out = os.path.join(output_dir, j)
            cv2.imwrite(name_out, image)
            
    print("DONE")

# %% [markdown]
# ## Creating masks

# %%
files_mask = glob.glob('/media/chaneu/Atlantyda/zuzki/mask/*')
files_photo = glob.glob('/media/chaneu/Atlantyda/zuzki/png/*')
print(len(files_mask))
print(len(files_photo))
phot_bef = files_mask[0].split("-")[1]
mask_bef = []
for i in files_mask:
    sp = i.split("-")
    orig_photo_name = files_photo[int(sp[1])-101].split("/")
    photo = cv2.imread(files_photo[int(sp[1])-101])
    tiff_name = '/media/chaneu/Atlantyda/zuzki/tiff/' + orig_photo_name[-1][:-3] +'tiff'
    mask = cv2.imread(i)
    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.erode(mask, kernel)
    name = '/media/chaneu/Atlantyda/zuzki/out/' + sp[-2] + '/' + sp[-1][:1] + '-' + orig_photo_name[-1] 
    name_p = '/media/chaneu/Atlantyda/zuzki/out_p/' + sp[-2] + '/' + sp[-1][:1] + '-' + orig_photo_name[-1] 
    name_t = '/media/chaneu/Atlantyda/zuzki/out_t/' + sp[-2] + '/' + sp[-1][:1] + '-' + orig_photo_name[-1][:-3] +'tiff'
    name_3d = '/media/chaneu/Atlantyda/zuzki/out_3d/' + sp[-2] + '/' + sp[-1][:1] + '-' + orig_photo_name[-1] 

    if sp[-2]=='conn_a':
        out = np.where(mask > 0, [1, 1, 1], mask)
    elif sp[-2]=='root':
        out = np.where(mask > 0, [2, 2, 2], mask)
    elif sp[-2]=='box':
        out = np.where(mask > 0, [3, 3, 3], mask)
    elif sp[-2]=='bag_a':
        out = np.where(mask > 0, [4, 4, 4], mask)
    elif sp[-2]=='bag_b':
        out = np.where(mask > 0, [5, 5, 5], mask)
    cv2.imwrite(name, out)
    cv2.imwrite(name_p, photo)
    # !cp $tiff_name $name_t

    tiff_image = Image.open(name_t)
    png_image = Image.open(name_p)
    tiff_tensor = ToTensor()(tiff_image)
    png_tensor = ToTensor()(png_image)
    merged_tensor = torch.cat((tiff_tensor, png_tensor), dim=0)
    merged_image = ToPILImage()(merged_tensor)
    merged_image.save(name_3d)

    #TEST IF THE PHOTO COMBINATION IS RIGHT
    h = '/media/chaneu/Atlantyda/zuzki/valid/'+ sp[-2] + '-' + sp[-1][:1] + '-' + orig_photo_name[-1]
    dst = cv2.addWeighted(photo, 0.5, mask.astype(np.uint8), 0.5, 0.0)
    cv2.imwrite(h, dst)
#     break
print("DONE")
# Out:
# 195
# 39
# cp: nie można utworzyć zwykłego pliku '/media/chaneu/Atlantyda/zuzki/out_t/bag_b/1-1686907306.495879_rgb.tiff': Nie ma takiego pliku ani katalogu
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 35
#      32 cv2.imwrite(name_p, photo)
#      33 get_ipython().system('cp $tiff_name $name_t')
# ---> 35 tiff_image = Image.open(name_t)
#      36 png_image = Image.open(name_p)
#      37 tiff_tensor = ToTensor()(tiff_image)
#
# File ~/.local/lib/python3.10/site-packages/PIL/Image.py:3131, in open(fp, mode, formats)
#    3128     filename = fp
#    3130 if filename:
# -> 3131     fp = builtins.open(filename, "rb")
#    3132     exclusive_fp = True
#    3134 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/chaneu/Atlantyda/zuzki/out_t/bag_b/1-1686907306.495879_rgb.tiff'

# %% [markdown]
# ## Merging masks in one

# %%
files_mask = glob.glob('/media/chaneu/Atlantyda/zuzki/mask/*')
files_photo = sorted(glob.glob('/media/chaneu/Atlantyda/zuzki/png/*'))
print(files_photo[0])
print(len(files_mask))

photo_bef = files_mask[0].split("-")[1]
end_list = []
for i in range(len(files_photo)):
    end_list.append([None, [], None, None, 
                     None, None, None]) # (photo, [mask list], photo path, mask path, tiff path in, tiff path put, 3d image path out)

for i in files_mask:
    sp = i.split("-")
    photo_num = int(sp[1])-1
    orig_photo_name = files_photo[photo_num].split("/")
    
    photo = cv2.imread(files_photo[photo_num])
    name = '/media/chaneu/Atlantyda/zuzki/out_one/' + orig_photo_name[-1] 
    name_p = '/media/chaneu/Atlantyda/zuzki/out_one_p/' + orig_photo_name[-1] 
    name_t = '/media/chaneu/Atlantyda/zuzki/out_one_t/' + orig_photo_name[-1][:-3] + 'tiff'
    name_t_in = '/media/chaneu/Atlantyda/zuzki/tiff/' + orig_photo_name[-1][:-3] + 'tiff'
    name_3d = '/media/chaneu/Atlantyda/zuzki/out_one_3d/' + orig_photo_name[-1]
    
    mask = cv2.imread(i)
    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.erode(mask, kernel)
    
    end_list[photo_num][0] = photo
    end_list[photo_num][2] = name_p
    end_list[photo_num][3] = name
    end_list[photo_num][4] = name_t_in
    end_list[photo_num][5] = name_t
    end_list[photo_num][6] = name_3d
    
    if sp[-2]=='conn_a':
        out = np.where(mask > 0, [1, 1, 1], mask)
    elif sp[-2]=='root':
        out = np.where(mask > 0, [2, 2, 2], mask)
    elif sp[-2]=='box':
        out = np.where(mask > 0, [3, 3, 3], mask)
    elif sp[-2]=='bag_a':
        out = np.where(mask > 0, [4, 4, 4], mask)
    elif sp[-2]=='bag_b':
        out = np.where(mask > 0, [5, 5, 5], mask)
        
    end_list[photo_num][1].append(out)
    photo_bef = sp[1]
    
for num, j in enumerate(end_list):
    clear_mask = np.zeros((j[0].shape[0], j[0].shape[1], j[0].shape[2]))

    for i in j[1]:
        clear_mask = np.where(i>0, i, clear_mask)    
        
    test_mask =  np.where(clear_mask>0, [255, 255, 255], clear_mask)
        
    cv2.imwrite(j[3], clear_mask)
    cv2.imwrite(j[2], j[0]) 
#     print(j[4], j[5])
    ni = j[4]
    no = j[5]
    # !cp $ni $no 
    
    tiff_image = Image.open(j[5])
    png_image = Image.open(j[2])
    tiff_tensor = ToTensor()(tiff_image)
    png_tensor = ToTensor()(png_image)
    merged_tensor = torch.cat((tiff_tensor, png_tensor), dim=0)
    merged_image = ToPILImage()(merged_tensor)
    merged_image.save(j[6])
    
    h = '/media/chaneu/Atlantyda/zuzki/valid/' + str(num) + '.png'
    dst = cv2.addWeighted(j[0], 0.5, test_mask.astype(np.uint8), 0.5, 0.0)
    cv2.imwrite(h, dst)
    

print("DONE")
# Out:
# /media/chaneu/Atlantyda/zuzki/png/1686564844.975126_rgb.png
# 195
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '33', 'annotation', '93', 'by', '1', 'tag', 'bag_a', '0.png']
# 32
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '33', 'annotation', '93', 'by', '1', 'tag', 'bag_a', '1.png']
# 32
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '33', 'annotation', '93', 'by', '1', 'tag', 'bag_b', '1.png']
# 32
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '33', 'annotation', '93', 'by', '1', 'tag', 'box', '0.png']
# 32
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '33', 'annotation', '93', 'by', '1', 'tag', 'conn_a', '0.png']
# 32
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '33', 'annotation', '93', 'by', '1', 'tag', 'root', '0.png']
# 32
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '37', 'annotation', '94', 'by', '1', 'tag', 'bag_a', '0.png']
# 36
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '37', 'annotation', '94', 'by', '1', 'tag', 'bag_a', '1.png']
# 36
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '37', 'annotation', '94', 'by', '1', 'tag', 'bag_b', '0.png']
# 36
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '37', 'annotation', '94', 'by', '1', 'tag', 'box', '0.png']
# 36
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '37', 'annotation', '94', 'by', '1', 'tag', 'root', '0.png']
# 36
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '29', 'annotation', '95', 'by', '1', 'tag', 'bag_a', '0.png']
# 28
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '29', 'annotation', '95', 'by', '1', 'tag', 'bag_a', '1.png']
# 28
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '29', 'annotation', '95', 'by', '1', 'tag', 'bag_b', '0.png']
# 28
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '29', 'annotation', '95', 'by', '1', 'tag', 'bag_b', '1.png']
# 28
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '29', 'annotation', '95', 'by', '1', 'tag', 'box', '0.png']
# 28
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '29', 'annotation', '95', 'by', '1', 'tag', 'conn_a', '0.png']
# 28
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '26', 'annotation', '96', 'by', '1', 'tag', 'bag_a', '0.png']
# 25
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '26', 'annotation', '96', 'by', '1', 'tag', 'bag_a', '1.png']
# 25
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '26', 'annotation', '96', 'by', '1', 'tag', 'bag_b', '0.png']
# 25
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '26', 'annotation', '96', 'by', '1', 'tag', 'bag_b', '1.png']
# 25
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '26', 'annotation', '96', 'by', '1', 'tag', 'box', '0.png']
# 25
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '26', 'annotation', '96', 'by', '1', 'tag', 'conn_a', '0.png']
# 25
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '16', 'annotation', '97', 'by', '1', 'tag', 'bag_a', '0.png']
# 15
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '16', 'annotation', '97', 'by', '1', 'tag', 'bag_b', '0.png']
# 15
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '16', 'annotation', '97', 'by', '1', 'tag', 'bag_b', '1.png']
# 15
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '16', 'annotation', '97', 'by', '1', 'tag', 'box', '0.png']
# 15
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '39', 'annotation', '98', 'by', '1', 'tag', 'bag_a', '0.png']
# 38
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '39', 'annotation', '98', 'by', '1', 'tag', 'bag_a', '1.png']
# 38
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '39', 'annotation', '98', 'by', '1', 'tag', 'bag_b', '0.png']
# 38
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '39', 'annotation', '98', 'by', '1', 'tag', 'bag_b', '1.png']
# 38
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '39', 'annotation', '98', 'by', '1', 'tag', 'box', '0.png']
# 38
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '39', 'annotation', '98', 'by', '1', 'tag', 'conn_a', '0.png']
# 38
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '39', 'annotation', '98', 'by', '1', 'tag', 'root', '0.png']
# 38
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '28', 'annotation', '99', 'by', '1', 'tag', 'bag_a', '0.png']
# 27
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '28', 'annotation', '99', 'by', '1', 'tag', 'bag_a', '1.png']
# 27
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '28', 'annotation', '99', 'by', '1', 'tag', 'bag_b', '0.png']
# 27
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '28', 'annotation', '99', 'by', '1', 'tag', 'bag_b', '1.png']
# 27
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '28', 'annotation', '99', 'by', '1', 'tag', 'box', '0.png']
# 27
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '28', 'annotation', '99', 'by', '1', 'tag', 'conn_a', '0.png']
# 27
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '10', 'annotation', '100', 'by', '1', 'tag', 'bag_b', '0.png']
# 9
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '10', 'annotation', '100', 'by', '1', 'tag', 'bag_b', '1.png']
# 9
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '11', 'annotation', '101', 'by', '1', 'tag', 'bag_a', '0.png']
# 10
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '11', 'annotation', '101', 'by', '1', 'tag', 'bag_a', '1.png']
# 10
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '11', 'annotation', '101', 'by', '1', 'tag', 'box', '0.png']
# 10
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '11', 'annotation', '101', 'by', '1', 'tag', 'conn_a', '0.png']
# 10
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '7', 'annotation', '102', 'by', '1', 'tag', 'bag_b', '0.png']
# 6
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '7', 'annotation', '102', 'by', '1', 'tag', 'bag_b', '1.png']
# 6
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '24', 'annotation', '106', 'by', '1', 'tag', 'bag_a', '0.png']
# 23
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '24', 'annotation', '106', 'by', '1', 'tag', 'bag_a', '1.png']
# 23
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '24', 'annotation', '106', 'by', '1', 'tag', 'bag_b', '0.png']
# 23
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '24', 'annotation', '106', 'by', '1', 'tag', 'bag_b', '1.png']
# 23
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '24', 'annotation', '106', 'by', '1', 'tag', 'box', '0.png']
# 23
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '24', 'annotation', '106', 'by', '1', 'tag', 'conn_a', '0.png']
# 23
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '12', 'annotation', '103', 'by', '1', 'tag', 'bag_a', '0.png']
# 11
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '12', 'annotation', '103', 'by', '1', 'tag', 'bag_a', '1.png']
# 11
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '12', 'annotation', '103', 'by', '1', 'tag', 'box', '0.png']
# 11
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '12', 'annotation', '103', 'by', '1', 'tag', 'conn_a', '0.png']
# 11
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '22', 'annotation', '104', 'by', '1', 'tag', 'bag_a', '0.png']
# 21
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '22', 'annotation', '104', 'by', '1', 'tag', 'bag_b', '0.png']
# 21
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '22', 'annotation', '104', 'by', '1', 'tag', 'conn_a', '0.png']
# 21
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '13', 'annotation', '105', 'by', '1', 'tag', 'bag_a', '0.png']
# 12
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '30', 'annotation', '108', 'by', '1', 'tag', 'bag_a', '0.png']
# 29
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '30', 'annotation', '108', 'by', '1', 'tag', 'bag_a', '1.png']
# 29
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '30', 'annotation', '108', 'by', '1', 'tag', 'bag_b', '0.png']
# 29
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '30', 'annotation', '108', 'by', '1', 'tag', 'bag_b', '1.png']
# 29
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '30', 'annotation', '108', 'by', '1', 'tag', 'box', '0.png']
# 29
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '15', 'annotation', '109', 'by', '1', 'tag', 'bag_a', '0.png']
# 14
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '15', 'annotation', '109', 'by', '1', 'tag', 'bag_a', '1.png']
# 14
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '15', 'annotation', '109', 'by', '1', 'tag', 'bag_b', '0.png']
# 14
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '15', 'annotation', '109', 'by', '1', 'tag', 'box', '0.png']
# 14
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '27', 'annotation', '117', 'by', '1', 'tag', 'bag_a', '0.png']
# 26
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '27', 'annotation', '117', 'by', '1', 'tag', 'bag_a', '1.png']
# 26
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '27', 'annotation', '117', 'by', '1', 'tag', 'bag_b', '1.png']
# 26
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '27', 'annotation', '117', 'by', '1', 'tag', 'box', '0.png']
# 26
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '27', 'annotation', '117', 'by', '1', 'tag', 'conn_a', '0.png']
# 26
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '8', 'annotation', '116', 'by', '1', 'tag', 'bag_b', '0.png']
# 7
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '8', 'annotation', '116', 'by', '1', 'tag', 'bag_b', '1.png']
# 7
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '34', 'annotation', '122', 'by', '1', 'tag', 'bag_a', '0.png']
# 33
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '34', 'annotation', '122', 'by', '1', 'tag', 'bag_a', '1.png']
# 33
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '34', 'annotation', '122', 'by', '1', 'tag', 'bag_b', '0.png']
# 33
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '34', 'annotation', '122', 'by', '1', 'tag', 'bag_b', '1.png']
# 33
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '34', 'annotation', '122', 'by', '1', 'tag', 'box', '0.png']
# 33
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '34', 'annotation', '122', 'by', '1', 'tag', 'conn_a', '0.png']
# 33
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '17', 'annotation', '121', 'by', '1', 'tag', 'bag_a', '0.png']
# 16
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '17', 'annotation', '121', 'by', '1', 'tag', 'bag_b', '0.png']
# 16
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '17', 'annotation', '121', 'by', '1', 'tag', 'bag_b', '1.png']
# 16
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '17', 'annotation', '121', 'by', '1', 'tag', 'box', '0.png']
# 16
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '18', 'annotation', '123', 'by', '1', 'tag', 'bag_a', '0.png']
# 17
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '18', 'annotation', '123', 'by', '1', 'tag', 'bag_a', '1.png']
# 17
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '18', 'annotation', '123', 'by', '1', 'tag', 'bag_b', '0.png']
# 17
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '18', 'annotation', '123', 'by', '1', 'tag', 'bag_b', '1.png']
# 17
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '18', 'annotation', '123', 'by', '1', 'tag', 'box', '0.png']
# 17
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '31', 'annotation', '124', 'by', '1', 'tag', 'bag_a', '0.png']
# 30
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '31', 'annotation', '124', 'by', '1', 'tag', 'bag_b', '0.png']
# 30
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '31', 'annotation', '124', 'by', '1', 'tag', 'bag_b', '1.png']
# 30
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '31', 'annotation', '124', 'by', '1', 'tag', 'box', '0.png']
# 30
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '31', 'annotation', '124', 'by', '1', 'tag', 'conn_a', '0.png']
# 30
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '31', 'annotation', '124', 'by', '1', 'tag', 'root', '0.png']
# 30
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '31', 'annotation', '124', 'by', '1', 'tag', 'root', '1.png']
# 30
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '38', 'annotation', '125', 'by', '1', 'tag', 'bag_a', '0.png']
# 37
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '38', 'annotation', '125', 'by', '1', 'tag', 'bag_a', '1.png']
# 37
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '38', 'annotation', '125', 'by', '1', 'tag', 'bag_b', '0.png']
# 37
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '38', 'annotation', '125', 'by', '1', 'tag', 'bag_b', '1.png']
# 37
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '38', 'annotation', '125', 'by', '1', 'tag', 'bag_b', '2.png']
# 37
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '38', 'annotation', '125', 'by', '1', 'tag', 'box', '0.png']
# 37
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '38', 'annotation', '125', 'by', '1', 'tag', 'conn_a', '0.png']
# 37
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '14', 'annotation', '126', 'by', '1', 'tag', 'bag_a', '0.png']
# 13
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '14', 'annotation', '126', 'by', '1', 'tag', 'bag_a', '1.png']
# 13
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '19', 'annotation', '127', 'by', '1', 'tag', 'bag_a', '0.png']
# 18
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '19', 'annotation', '127', 'by', '1', 'tag', 'bag_a', '1.png']
# 18
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '19', 'annotation', '127', 'by', '1', 'tag', 'bag_b', '0.png']
# 18
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '19', 'annotation', '127', 'by', '1', 'tag', 'box', '0.png']
# 18
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '19', 'annotation', '127', 'by', '1', 'tag', 'conn_a', '0.png']
# 18
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '23', 'annotation', '128', 'by', '1', 'tag', 'bag_a', '0.png']
# 22
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '23', 'annotation', '128', 'by', '1', 'tag', 'bag_a', '1.png']
# 22
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '23', 'annotation', '128', 'by', '1', 'tag', 'bag_b', '0.png']
# 22
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '23', 'annotation', '128', 'by', '1', 'tag', 'box', '0.png']
# 22
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '23', 'annotation', '128', 'by', '1', 'tag', 'conn_a', '0.png']
# 22
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '23', 'annotation', '128', 'by', '1', 'tag', 'root', '0.png']
# 22
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '9', 'annotation', '129', 'by', '1', 'tag', 'bag_a', '0.png']
# 8
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '9', 'annotation', '129', 'by', '1', 'tag', 'bag_b', '0.png']
# 8
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '9', 'annotation', '129', 'by', '1', 'tag', 'bag_b', '1.png']
# 8
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '36', 'annotation', '130', 'by', '1', 'tag', 'bag_a', '0.png']
# 35
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '36', 'annotation', '130', 'by', '1', 'tag', 'bag_a', '1.png']
# 35
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '36', 'annotation', '130', 'by', '1', 'tag', 'bag_b', '1.png']
# 35
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '36', 'annotation', '130', 'by', '1', 'tag', 'box', '0.png']
# 35
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '36', 'annotation', '130', 'by', '1', 'tag', 'conn_a', '0.png']
# 35
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '36', 'annotation', '130', 'by', '1', 'tag', 'root', '0.png']
# 35
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '25', 'annotation', '131', 'by', '1', 'tag', 'bag_a', '0.png']
# 24
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '25', 'annotation', '131', 'by', '1', 'tag', 'bag_a', '1.png']
# 24
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '25', 'annotation', '131', 'by', '1', 'tag', 'bag_b', '0.png']
# 24
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '25', 'annotation', '131', 'by', '1', 'tag', 'box', '0.png']
# 24
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '25', 'annotation', '131', 'by', '1', 'tag', 'conn_a', '0.png']
# 24
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '21', 'annotation', '107', 'by', '1', 'tag', 'bag_a', '0.png']
# 20
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '21', 'annotation', '107', 'by', '1', 'tag', 'bag_a', '1.png']
# 20
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '21', 'annotation', '107', 'by', '1', 'tag', 'bag_b', '0.png']
# 20
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '21', 'annotation', '107', 'by', '1', 'tag', 'bag_b', '1.png']
# 20
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '21', 'annotation', '107', 'by', '1', 'tag', 'box', '0.png']
# 20
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '20', 'annotation', '120', 'by', '1', 'tag', 'bag_a', '0.png']
# 19
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '20', 'annotation', '120', 'by', '1', 'tag', 'bag_a', '1.png']
# 19
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '20', 'annotation', '120', 'by', '1', 'tag', 'bag_b', '0.png']
# 19
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '20', 'annotation', '120', 'by', '1', 'tag', 'bag_b', '1.png']
# 19
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '20', 'annotation', '120', 'by', '1', 'tag', 'box', '0.png']
# 19
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '20', 'annotation', '120', 'by', '1', 'tag', 'conn_a', '0.png']
# 19
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '32', 'annotation', '119', 'by', '1', 'tag', 'bag_a', '0.png']
# 31
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '32', 'annotation', '119', 'by', '1', 'tag', 'bag_a', '1.png']
# 31
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '32', 'annotation', '119', 'by', '1', 'tag', 'bag_b', '0.png']
# 31
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '32', 'annotation', '119', 'by', '1', 'tag', 'bag_b', '1.png']
# 31
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '32', 'annotation', '119', 'by', '1', 'tag', 'box', '0.png']
# 31
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '32', 'annotation', '119', 'by', '1', 'tag', 'conn_a', '0.png']
# 31
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '32', 'annotation', '119', 'by', '1', 'tag', 'root', '0.png']
# 31
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '35', 'annotation', '118', 'by', '1', 'tag', 'bag_a', '0.png']
# 34
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '35', 'annotation', '118', 'by', '1', 'tag', 'bag_a', '1.png']
# 34
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '35', 'annotation', '118', 'by', '1', 'tag', 'bag_b', '0.png']
# 34
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '35', 'annotation', '118', 'by', '1', 'tag', 'bag_b', '1.png']
# 34
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '35', 'annotation', '118', 'by', '1', 'tag', 'box', '0.png']
# 34
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '35', 'annotation', '118', 'by', '1', 'tag', 'conn_a', '0.png']
# 34
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '6', 'annotation', '115', 'by', '1', 'tag', 'bag_b', '0.png']
# 5
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '6', 'annotation', '115', 'by', '1', 'tag', 'bag_b', '1.png']
# 5
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '2', 'annotation', '114', 'by', '1', 'tag', 'bag_a', '0.png']
# 1
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '2', 'annotation', '114', 'by', '1', 'tag', 'bag_a', '1.png']
# 1
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '2', 'annotation', '114', 'by', '1', 'tag', 'bag_b', '0.png']
# 1
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '2', 'annotation', '114', 'by', '1', 'tag', 'bag_b', '1.png']
# 1
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '2', 'annotation', '114', 'by', '1', 'tag', 'box', '0.png']
# 1
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '2', 'annotation', '114', 'by', '1', 'tag', 'conn_a', '0.png']
# 1
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '4', 'annotation', '113', 'by', '1', 'tag', 'bag_a', '0.png']
# 3
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '4', 'annotation', '113', 'by', '1', 'tag', 'bag_a', '1.png']
# 3
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '4', 'annotation', '113', 'by', '1', 'tag', 'bag_b', '0.png']
# 3
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '4', 'annotation', '113', 'by', '1', 'tag', 'bag_b', '1.png']
# 3
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '4', 'annotation', '113', 'by', '1', 'tag', 'box', '0.png']
# 3
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '5', 'annotation', '112', 'by', '1', 'tag', 'bag_a', '0.png']
# 4
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '5', 'annotation', '112', 'by', '1', 'tag', 'bag_a', '1.png']
# 4
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '5', 'annotation', '112', 'by', '1', 'tag', 'bag_b', '0.png']
# 4
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '5', 'annotation', '112', 'by', '1', 'tag', 'box', '0.png']
# 4
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '5', 'annotation', '112', 'by', '1', 'tag', 'conn_a', '0.png']
# 4
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '5', 'annotation', '112', 'by', '1', 'tag', 'root', '0.png']
# 4
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '3', 'annotation', '111', 'by', '1', 'tag', 'bag_a', '0.png']
# 2
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '3', 'annotation', '111', 'by', '1', 'tag', 'bag_a', '1.png']
# 2
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '3', 'annotation', '111', 'by', '1', 'tag', 'bag_b', '0.png']
# 2
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '3', 'annotation', '111', 'by', '1', 'tag', 'bag_b', '1.png']
# 2
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '3', 'annotation', '111', 'by', '1', 'tag', 'box', '0.png']
# 2
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '3', 'annotation', '111', 'by', '1', 'tag', 'conn_a', '0.png']
# 2
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '1', 'annotation', '110', 'by', '1', 'tag', 'bag_a', '0.png']
# 0
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '1', 'annotation', '110', 'by', '1', 'tag', 'bag_a', '1.png']
# 0
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '1', 'annotation', '110', 'by', '1', 'tag', 'bag_b', '0.png']
# 0
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '1', 'annotation', '110', 'by', '1', 'tag', 'bag_b', '1.png']
# 0
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '1', 'annotation', '110', 'by', '1', 'tag', 'box', '0.png']
# 0
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '1', 'annotation', '110', 'by', '1', 'tag', 'conn_a', '0.png']
# 0
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '36', 'annotation', '130', 'by', '1', 'tag', 'bag_b', '0.png']
# 35
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '13', 'annotation', '105', 'by', '1', 'tag', 'box', '0.png']
# 12
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '22', 'annotation', '104', 'by', '1', 'tag', 'box', '0.png']
# 21
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '25', 'annotation', '131', 'by', '1', 'tag', 'bag_b', '1.png']
# 24
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '27', 'annotation', '117', 'by', '1', 'tag', 'bag_b', '0.png']
# 26
# ['/media/chaneu/Atlantyda/zuzki/mask/task', '33', 'annotation', '93', 'by', '1', 'tag', 'bag_b', '0.png']
# 32
# after
# DONE

# %% [markdown]
# ## Checking mask values

# %%
def check_mask_values(path):
    folder = glob.glob(path + '/*.png')
    folder.sort()
    for i in folder:
        print('----------')
#         print(i)
        mask = cv2.imread(i)
        gray = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
        liczby = []
        new = False
        n = True

        for k in range(mask.shape[0]):
            for j in range(mask.shape[1]):
                if (gray[k][j] > 0 and n):
                    liczby.append(gray[k][j])
                    n = False
                if (gray[k][j] > 0 and n==False):
                    new=True
                    for i in liczby:
                        if i==gray[k][j]:
                            new=False

                if new and gray[k][j] != 0:
                    liczby.append(gray[k][j])
    
        print("Found contours:", liczby)
        for i in liczby:
            if (i>5):
                print(i)
check_mask_values('/media/chaneu/Atlantyda/na _porthosa_03_08/31.07/dataset/masks/val')
# Out:
# ----------
# Found contours: [2, 3, 4, 1, 5]
# ----------
# Found contours: [2, 4, 3, 1, 5]
# ----------
# Found contours: [2, 4, 3, 1, 5]
# ----------
# Found contours: [2, 3, 4, 5, 1]
# ----------
# Found contours: [2, 3, 4, 5, 1]
# ----------
# Found contours: [2, 3, 5, 1, 4]
# ----------
# Found contours: [2, 1, 3, 4, 5]
# ----------
# Found contours: [2, 1, 3, 4, 5]
# ----------
# Found contours: [2, 1, 3, 4, 5]
# ----------
# Found contours: [2, 3, 4, 1, 5]
# ----------
# Found contours: [3, 4, 1, 5]
# ----------
# Found contours: [2, 3, 4, 1, 5]
# ----------
# Found contours: [2, 3, 4, 1, 5]
# ----------
# Found contours: [3, 4, 1, 5]
# ----------
# Found contours: [4, 3, 5, 1]
# ----------
# Found contours: [2, 4, 3, 5, 1]
# ----------
# Found contours: [2, 4, 3, 5, 1]
# ----------
# Found contours: [1, 4, 5, 3]
# ----------
# Found contours: [2, 5, 3, 4, 1]
# ----------
# Found contours: [2, 3, 5, 4, 1]
# ----------
# Found contours: [2, 3, 1, 5, 4]
# ----------
# Found contours: [2, 3, 5, 4]
# ----------
# Found contours: [2, 3, 1, 4, 5]
# ----------
# Found contours: [2, 3, 4, 1, 5]
# ----------
# Found contours: [2, 3, 1, 4, 5]
# ----------
# Found contours: [2, 3, 4, 1, 5]
# ----------
# Found contours: [2, 3, 1, 4, 5]
# ----------
# Found contours: [3, 1, 4, 5]
# ----------
# Found contours: [3, 1, 4, 5]
# ----------
# Found contours: [3, 1, 4, 5]
# ----------
# Found contours: [2, 3, 1, 4, 5]

# %% [markdown]
# ## Creating mask with given values

# %%
def make_mask_values():
    folder = ['conn_a', 'root', 'box', 'bag_a', 'bag_b'] #name of the folders

    for num1, c in enumerate(folder):
        num = num1 + 1 #value of the mask
        path_wy = '/media/chaneu/Atlantyda/Magi_210623/mask_NOT/' + c + '/'
        path_we = glob.glob('/media/chaneu/Atlantyda/Magi_210623/mask/' + c + '/*.png')

        for i in path_we:
            name = i[-25:]
            print(i)
            filename = os.path.join(path_wy, name)
            maska = cv2.imread(i)
            maska = np.where(maska == [255, 255, 255], [num, num, num], maska)
            cv2.imwrite(filename, maska)


    print("DONE")
make_mask_values()
# Out:
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062261.097937_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062327.792367_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062366.485797_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062392.054024_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062420.029804_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062461.115286_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062471.036019_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062486.764592_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062500.048631_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062514.910067_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062534.106420_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062553.584822_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062564.181064_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062584.832670_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062598.828553_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062604.519382_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062609.394475_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062626.113270_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062651.415138_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062673.329564_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062694.398604_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062716.168654_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062732.182704_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062740.112313_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062795.052391_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062815.535405_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062830.108100_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062844.700088_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062867.127351_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062890.641819_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062905.434675_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062912.934159_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/conn_a/1677062930.500813_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072768.704181_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072794.979177_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072806.399216_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072814.876263_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072823.484096_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072837.532976_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072843.403763_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072849.594220_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072856.551221_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072864.858735_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072884.844886_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072929.225706_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072951.250727_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072969.384842_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072980.532795_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677072988.263698_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073025.118313_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073042.367327_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073053.685372_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073086.615247_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073094.853209_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073109.064703_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073129.913259_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073146.925209_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073154.055269_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073181.921779_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073189.719544_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073227.840885_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073255.844828_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073268.220688_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073284.002887_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073291.233837_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/root/1677073304.769675_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664207.532626_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664237.153122_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664246.327276_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664261.307687_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664273.852505_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664294.673658_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664304.637540_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664311.278066_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664319.762523_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664337.795872_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664351.338458_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664365.621448_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664390.100984_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664413.061555_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664439.402894_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664466.232339_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664486.403330_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664490.861342_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664495.196291_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664506.447082_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664517.277501_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664530.045897_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664541.842515_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664594.236704_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664606.355321_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664615.505327_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664631.027125_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664637.294088_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664645.800349_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664672.135563_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664685.293272_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664693.135746_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664706.069352_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664725.596799_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664745.065408_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664758.054730_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664765.592338_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664789.645748_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664802.324832_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664818.720403_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664842.131313_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664853.671128_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664862.721020_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/box/1677664900.075747_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677662835.347660_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677662843.827511_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677662852.712515_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677662946.655071_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677662959.365401_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663026.301491_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663144.095005_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663152.028713_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663168.180035_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663195.969641_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663218.111560_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663234.432637_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663338.978793_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663347.863984_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663370.638850_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663377.334659_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663397.420390_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663419.801594_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663445.809851_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663485.657485_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663495.471815_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663544.292428_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663553.442306_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663563.707589_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663584.540894_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663609.367964_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663671.743560_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663695.196239_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663706.754986_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663772.963128_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663942.211087_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663986.010630_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677663998.077727_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677664008.105671_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677664016.718794_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_a/1677664032.776021_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677660815.546084_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677660828.223144_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677660854.545238_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677660880.834371_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677660892.140445_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677660899.926581_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677660911.897337_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677660984.633028_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677660996.652379_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661009.290674_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661026.686013_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661059.453598_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661092.405299_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661118.654365_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661301.945739_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661331.546679_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661359.866034_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661367.909490_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661389.403221_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661430.031495_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661449.033148_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661683.383532_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661706.223784_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661864.061039_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661874.610024_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677661893.048442_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662056.233746_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662075.189354_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662107.456249_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662114.560153_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662120.982175_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662130.422532_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662140.173325_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662163.671471_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662179.482212_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662237.087058_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662251.980246_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662361.158489_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662382.050862_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662387.958110_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662396.270898_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662407.491270_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662418.452649_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662427.461567_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662439.638252_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662457.669606_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662489.875126_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662504.172068_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662518.332281_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662546.496761_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662559.363938_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662581.264313_rgb.png
# /media/chaneu/Atlantyda/Magi_210623/mask/bag_b/1677662603.448346_rgb.png
# DONE

# %%
# !rm /home/chaneu/Magi/YOLO/labels/train/1677069752.295090_rgb.txt

# %% [markdown]
# ## Check compatibility of files

# %%
def check_compatibility_of_files(folder01, folder02, letters):
    folder1 = glob.glob(folder01 + '/*')
    folder2 = glob.glob(folder02 + '/*')
    
    for i in folder1:
        find = False
        for j in folder2:
            if i[-25:-3] == j[-26:-4]:   
                find = True
                break
        if find:
            continue
        else:
            print(i, "first NO pair")           
            
    for i in folder2:
        find = False
        for j in folder1:
            if i[-26:-4] == j[-25:-3]:
                find = True
                break
        if find:
            continue
        else:
            print(i, "second NO pair")
            # !rm $i
            
            
    print("checking compatibility end")
                
check_compatibility_of_files("/media/chaneu/Atlantyda/new/out_one_p/", "/media/chaneu/Atlantyda/new/out_one_t/", -25) #first folder, second folder,
# Out:
# /media/chaneu/Atlantyda/new/out_one_t/1686902867.528350_rgb.tiff second NO pair
# /media/chaneu/Atlantyda/new/out_one_t/1686906104.480313_rgb.tiff second NO pair
# /media/chaneu/Atlantyda/new/out_one_t/1686906433.966975_rgb.tiff second NO pair
# /media/chaneu/Atlantyda/new/out_one_t/1686906753.334741_rgb.tiff second NO pair
# /media/chaneu/Atlantyda/new/out_one_t/1686907907.380406_rgb.tiff second NO pair
# /media/chaneu/Atlantyda/new/out_one_t/1686909438.805710_rgb.tiff second NO pair
# /media/chaneu/Atlantyda/new/out_one_t/1686909866.001532_rgb.tiff second NO pair
# checking compatibility end

# %% [markdown]
# ## Change file names

# %%
# 000000111 000111000
def change_file_name():
    path = '/media/chaneu/Atlantyda/aug/end_augmented_txt/'
    files = glob.glob(path + '*')
    for i in files:
        name = path+ '111' + '111' + i[-7:-4]+ '.txt' 
#         print(name, i)
#         break
#         !mv $i $name
change_file_name()

# %% [markdown]
# ## Resize image

# %%
def resise_images(image_folder):
    once = True
    folder = ['conn_a', 'conn_b', 'conn_c', 'root', 'conn_d', 'conn_e', 'conn_f','conn_g', 'conn_h', 
              'conn_i', 'conn_j', 'conn_k', 'box', 'bag_red', 'bag_b_s', 'bag_b_b']
    for i in folder:
        path_out = '/home/chaneu/Magi/image_out_768_512/' + i 
        images = glob.glob(image_folder + '/' + i + '/*.png')
        os.makedirs(path_out)
                
        for j in images:
            image = cv2.imread(j)
            image2 = cv2.resize(image, (768, 512), interpolation = cv2.INTER_AREA)
            name = j[-25:]
            filename = os.path.join(path_out, name)
            cv2.imwrite(filename, image2)
    print('done')

                            
resise_images('/home/chaneu/Magi/image')
